# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/my_dataset.csv')

# %%
print(df.describe())
# Out:
#        feature1  feature2    target
# count  9.000000  9.000000  9.000000
# mean   4.988889  3.333333  0.444444
# std    0.344400  0.316228  0.527046
# min    4.600000  2.900000  0.000000
# 25%    4.700000  3.100000  0.000000
# 50%    5.000000  3.400000  0.000000
# 75%    5.100000  3.500000  1.000000
# max    5.600000  3.900000  1.000000

# %%
sns.pairplot(df, hue='target')
plt.show()
